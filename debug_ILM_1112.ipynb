# %%
import random
import os
from datetime import datetime
from chunk import Chunk
from chunk.Visualize_Operations_Number import visualize_operations_number
from category_integration import Category_Integration 
from replace import Replace
from production import Production
from topsim import TopSim
from topsim.Normalized_TopSim import Normalized_TopSim
from topsim import Visualize_TopSim
from topsim.Ibuki_1_TopSim import Ibuki_1_TopSim
from expressivity import Expressivity
from expressivity.Visualize_Expressivity import visualize_expressivity
from expressivity.Visualize_TopSim_and_Expressivity import visualize_combined_metrics


class Agent:
    def __init__(self, name, learning_algorithms=None):
        self.name = name
        self.memory = []
        self.meanings_for_production = []
        self.production = []
        self.learning_algorithms = learning_algorithms if learning_algorithms else ['chunk', 'category_integration', 'replace']
        self.chunk_application_count = 0  # 各世代のチャンク適用回数をカウント
        self.category_integration_count = 0
        self.replace_application_count = 0
        self.label_conversion_history = {}  # カテゴリー統合の変換履歴を保持

    def learn_language(self, rule_set, iterations=3, batch_size=5):
        learned_rules = []
        chunk_application_count = 0  # 世代ごとのチャンク適用回数
        category_integration_count = 0
        replace_application_count = 0
        
        for i in range(0, len(rule_set), batch_size):
            batch = rule_set[i:i + batch_size]
            current_batch = learned_rules + batch

            for _ in range(iterations):
                for algorithm in self.learning_algorithms:
                    if algorithm == 'chunk':
                        current_batch, chunk_applications = Chunk.chunk_learning(current_batch)
                        chunk_application_count += chunk_applications
                    elif algorithm == 'category_integration':
                        # `label_conversion_history` を追加で渡す
                        current_batch, category_applications = Category_Integration.category_integration_learning(
                            current_batch, self.label_conversion_history
                        )
                        category_integration_count += category_applications
                    elif algorithm == 'replace':
                        current_batch, replace_applications = Replace.replace_learning(current_batch)
                        replace_application_count += replace_applications

            learned_rules = current_batch

        self.memory = learned_rules
        self.chunk_application_count = chunk_application_count  # 最終的な適用回数を保存
        self.category_integration_count = category_integration_count
        self.replace_application_count = replace_application_count

    def produce_language(self, rule_set, all_meanings, holistic_rule_invention_length, word_rule_invention_length, max_form_length, front_keep_length, shortening_interval, generation):
        # 全ての意味空間に基づいて発話を生成する
        self.production = Production.produce(
            rule_set, 
            all_meanings,  # ここでは意味空間全体に基づいて発話を行う
            holistic_rule_invention_length, 
            word_rule_invention_length,
            max_form_length, 
            front_keep_length,
            shortening_interval,
            generation
        )
        return self.production

def sample_meaning_space(file_path):
    """意味空間全体を読み込む"""
    with open(file_path) as f:
        s = f.read()
        meanings = s.split(",\n")
    return meanings

def simulate_language_evolution(
    n_gens, 
    n_samples, 
    initial_language_file, 
    semantic_space_file, 
    holistic_rule_invention_length, 
    word_rule_invention_length, 
    random_seed=1, 
    iterations=3, 
    batch_size=5,
    max_form_length=9,
    front_keep_length=3,
    shortening_interval=30
):
    # 乱数のシードを設定
    random.seed(random_seed)
    
    parent = Agent(name="Parent")
    child = Agent(name="Child", learning_algorithms=['chunk', 'category_integration', 'replace'])

    now = datetime.now()
    timestamp = now.strftime('%Y%m%d_%H%M%S')
    base_folder = f"out/exp{timestamp}"
    os.makedirs(base_folder, exist_ok=True)
    
    generation_folder = os.path.join(base_folder, "generations")
    os.makedirs(generation_folder, exist_ok=True)

    topsim_values = []
    normalized_topsim_values = []  # Normalized_TopSimのリスト
    ibuki_1_topsim_values = []
    expressivity_values = [0]
    chunk_application_counts = [0]  # 各世代のチャンク適用回数を保持するリスト
    category_integration_counts = [0]
    replace_application_counts = [0]
    knowledge_counts = [0]  # 各世代の言語知識の数を保持するリスト

    # 1世代目の親の発話に必要な意味空間全体を取得（初期言語ファイルから）
    all_meanings = sample_meaning_space(file_path=initial_language_file)
    
    
    parent.production = sample_meaning_space(initial_language_file)
    child_samples = parent.production
    
    
    # print(f"世代1の親の発話: {parent.production}")#------------------------1111
    with open(os.path.join(generation_folder, "gen-1.txt"), 'w') as f:
        f.write("\n".join(parent.production))

    # print(f"世代1の子の受け取った発話: {child_samples}")#------------------------1111
    child.learn_language(child_samples, iterations=iterations)
    
    # 各世代のチャンク適用回数をリストに追加
    chunk_application_counts.append(child.chunk_application_count)
    category_integration_counts.append(child.category_integration_count)
    replace_application_counts.append(child.replace_application_count)
    knowledge_counts.append(len(child.memory))  # 言語知識の数を記録
    # print(f"世代 1 の子の言語知識: {child.memory}") #------------------------1111

    # 全ての発話に対してTopSimを計算
    topsim_values.append(TopSim.TopSim(parent.production))
    normalized_topsim_values.append(Normalized_TopSim(parent.production))
    ibuki_1_topsim_values.append(Ibuki_1_TopSim(parent.production))  # Ibuki_1_TopSim値の追加


    # 2世代目以降の処理
    for generation in range(2, n_gens + 1):
        # 2世代目以降の意味空間を全て取得
        all_meanings = sample_meaning_space(file_path=semantic_space_file)

        # 親が意味空間全体に基づいて発話する
        parent.production = parent.produce_language(
            rule_set=child.memory,  # 子供の学習結果が親のルールセットになる
            all_meanings=all_meanings,
            holistic_rule_invention_length=holistic_rule_invention_length,
            word_rule_invention_length=word_rule_invention_length,
            max_form_length=max_form_length,
            front_keep_length=front_keep_length,
            shortening_interval=shortening_interval,
            generation=generation
        )
        with open(os.path.join(generation_folder, f"gen-{generation}.txt"), 'w') as f:
            f.write("\n".join(parent.production))
            
        # print(f"世代 {generation} の親の発話: {parent.production}") #------------------------1111


        # 子供に学習データを渡す（n_samplesだけランダムに選ぶ）
        child_samples = random.sample(parent.production, n_samples)
        # print(f"世代 {generation} の子の受け取った発話: {child_samples}")#------------------------1111
        child.learn_language(child_samples, iterations=iterations)
        # print(f"世代 {generation} の 子の言語知識: {child.memory}")#------------------------1111

        
        # 各世代のチャンク適用回数をリストに追加
        chunk_application_counts.append(child.chunk_application_count)
        category_integration_counts.append(child.category_integration_count)
        replace_application_counts.append(child.replace_application_count)
        knowledge_counts.append(len(child.memory))  # 言語知識の数を記録

        # 各世代のTopSim値を計算
        topsim_values.append(TopSim.TopSim(parent.production))
        normalized_topsim_values.append(Normalized_TopSim(parent.production))
        ibuki_1_topsim_values.append(Ibuki_1_TopSim(parent.production))  # Ibuki_1_TopSim値の追加


        # 各世代のExpressivity値を計算
        all_meanings = sample_meaning_space(semantic_space_file)
        expressivity_value = Expressivity.expressivity(child.memory, all_meanings)  # child.memoryをrule_setとして扱う
        expressivity_values.append(expressivity_value)

    
    # Combined TopSim and Expressivity の結果をプロット
    combined_plot_path = os.path.join(base_folder, "combined_transition.png")
    visualize_combined_metrics(topsim_values, normalized_topsim_values, ibuki_1_topsim_values, expressivity_values, n_gens, combined_plot_path)
    
    # 各アルゴリズムの適用回数の推移をプロット
    operations_plot_path = os.path.join(base_folder, "operations_count_transition.png")
    visualize_operations_number(chunk_application_counts, category_integration_counts, replace_application_counts, knowledge_counts, n_gens, operations_plot_path)



    # 必要なすべての変数を返す
    return parent.production, child_samples, child.memory, topsim_values, normalized_topsim_values, ibuki_1_topsim_values, expressivity_values, chunk_application_counts, category_integration_counts, replace_application_counts

# 実行部分 (__main__)
if __name__ == "__main__":
    
    # パラメータ
    N_GENS = 200  # 世代数
    N_SAMPLES = 24  # 子供が学習するデータ数
    INITIAL_LANGUAGE_FILE = "data/debug_48_1110.txt"  # 1世代目の初期言語ファイル
    SEMANTIC_SPACE_FILE = "data/48_Semantic_Space_0.txt"  # 2世代目以降の意味空間ファイル
    HOLISTIC_RULE_INVENTION_LENGTH = 6  # 文全体のルールの最大長さ
    WORD_RULE_INVENTION_LENGTH = 1  # 単語ルールの最大長さ
    ITERATIONS = 4  # 学習アルゴリズムの反復回数
    BATCH_SIZE = 12  # 何個ずつバッチに分けて学習するか
    MAX_FORM_LENGTH = 9  # 形式の最大長さ
    FRONT_KEEP_LENGTH = 6  # 前半に残す長さ
    SHORTENING_INTERVAL = 10
    SEED_MAX = 5  # シードの最大値（1～5）

    # SEED_RANGE の各シードで実験を実行
    for seed in range(1, SEED_MAX + 1):
        print(f"Experiment with seed: {seed}")  # シードの表示

        # シミュレーションの実行
        parent_production, child_samples, child_memory, topsim_values, normalized_topsim_values, ibuki_1_topsim_values, expressivity_values, chunk_application_counts, category_integration_counts, replace_application_counts = simulate_language_evolution(
            n_gens=N_GENS, 
            n_samples=N_SAMPLES, 
            initial_language_file=INITIAL_LANGUAGE_FILE, 
            semantic_space_file=SEMANTIC_SPACE_FILE,
            holistic_rule_invention_length=HOLISTIC_RULE_INVENTION_LENGTH,
            word_rule_invention_length=WORD_RULE_INVENTION_LENGTH,
            random_seed=seed,  # 各シードで実行
            iterations=ITERATIONS,
            batch_size=BATCH_SIZE,
            max_form_length=MAX_FORM_LENGTH,  # 形式の最大長さ
            front_keep_length=FRONT_KEEP_LENGTH,  # 前半に残す長さ
            shortening_interval=SHORTENING_INTERVAL
        )

        # 結果の表示
        print(f"最終世代の発話seed{seed}:", parent_production)
        print(f"最終世代の子供が受け取った発話seed{seed}:", child_samples)
        print(f"最終世代の子供の記憶seed{seed}:", child_memory)
        print(f"各世代のTopSim値seed{seed}:", topsim_values)
        print(f"各世代のNormalized_TopSim値seed{seed}:", normalized_topsim_values)
        print(f"各世代のIbuki_1_TopSim値seed{seed}:", ibuki_1_topsim_values)
        print(f"各世代のExpressivity値seed{seed}:", expressivity_values)
        print(f"各世代のチャンク適用回数seed{seed}:", chunk_application_counts)
        print(f"各世代のカテゴリ統合適用回数seed{seed}:", category_integration_counts)
        print(f"各世代のリプレース適用回数seed{seed}:", replace_application_counts)
        print("-" * 50)  # 区切りを追加
# Out:
# Experiment with seed: 1
# word_rule_set []
# rule_set ['S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_david)/0->jvu', 'S/_eat(_carol,_bob)/0->kng']
# compare_form_pair_results [('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['jvu'], ['kng'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels set()
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_david)/0->jvu', 'S/_eat(_carol,_bob)/0->kng']
# word_rule_set []
# rule_set ['S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_david)/0->jvu', 'S/_eat(_carol,_bob)/0->kng']
# compare_form_pair_results [('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['jvu'], ['kng'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels set()
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_david)/0->jvu', 'S/_eat(_carol,_bob)/0->kng']
# word_rule_set []
# rule_set ['S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_david)/0->jvu', 'S/_eat(_carol,_bob)/0->kng']
# compare_form_pair_results [('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['jvu'], ['kng'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels set()
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_david)/0->jvu', 'S/_eat(_carol,_bob)/0->kng']
# word_rule_set []
# rule_set ['S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_david)/0->jvu', 'S/_eat(_carol,_bob)/0->kng']
# compare_form_pair_results [('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['jvu'], ['kng'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels set()
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_david)/0->jvu', 'S/_eat(_carol,_bob)/0->kng']
# word_rule_set []
# rule_set ['S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_david)/0->jvu', 'S/_eat(_carol,_bob)/0->kng', 'S/_hel(_david,_bob)/0->bnfr', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_hel(_david,_alice)/0->bje', 'S/_hel(_carol,_david)/0->znu']
# compare_form_pair_results [('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['quw'], ['bnfr']), ('1', ['lcm'], ['bje']), ('1', ['jvu'], ['kng']), ('10', ['jv', 'u'], ['zn', 'u']), ('01', ['b', 'nfr'], ['b', 'je'])]
# filtered_indices_set [5, 6]
# can_chunk_rule_set [['S/_eat(_carol,_david)/0->jvu', 'S/_hel(_carol,_david)/0->znu'], ['S/_hel(_david,_bob)/0->bnfr', 'S/_hel(_david,_alice)/0->bje']]
# split_sem_pairs [[['S', '_eat', '_carol', '_david', '/0'], ['S', '_hel', '_carol', '_david', '/0']], [['S', '_hel', '_david', '_bob', '/0'], ['S', '_hel', '_david', '_alice', '/0']]]
# index_sem_difference_sets [[1], [3]]
# transform_only_form_chunk_pair_sets [['jvu', 'znu'], ['bnfr', 'bje']]
# split_form_pairs [(['jv', 'u'], ['zn', 'u']), (['b', 'nfr'], ['b', 'je'])]
# index_form_difference_sets [[0], [1]]
# used_labels set()
# ===========-=========--
# チャンクしたペア [([['S', '_p', '_carol', '_david', '/0'], ['A/p', 'u']], [['A', '_eat'], ['jv']], [['A', '_hel'], ['zn']]), ([['S', '_hel', '_david', '_y', '/0'], ['b', 'Σ/y']], [['Σ', '_bob'], ['nfr']], [['Σ', '_alice'], ['je']])]
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'A/_eat->jv', 'A/_hel->zn', 'S/_hel(_david,_y)/0->bΣ/y', 'Σ/_bob->nfr', 'Σ/_alice->je', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm']
# compare_form_pair_results [('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm']
# compare_form_pair_results [('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm']
# compare_form_pair_results [('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf']
# compare_form_pair_results [('2', ['A/p', 'u'], ['knl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['kng'], ['fft']), ('1', ['frm'], ['qaq']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['knl'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf']
# compare_form_pair_results [('2', ['A/p', 'u'], ['knl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['kng'], ['fft']), ('1', ['frm'], ['qaq']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['knl'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf']
# compare_form_pair_results [('2', ['A/p', 'u'], ['knl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['kng'], ['fft']), ('1', ['frm'], ['qaq']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['knl'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf']
# compare_form_pair_results [('2', ['A/p', 'u'], ['knl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['kng'], ['fft']), ('1', ['frm'], ['qaq']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['knl'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_david,_carol)/0->ikv', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_hel(_bob,_carol)/0->jhv']
# compare_form_pair_results [('2', ['A/p', 'u'], ['knl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['kng'], ['fft']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['frm'], ['qaq']), ('1', ['frm'], ['jhv']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['knl']), ('1', ['fft'], ['cbc']), ('1', ['zbhw'], ['agt']), ('1', ['ikv'], ['agt']), ('1', ['cbc'], ['agt'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_david,_carol)/0->ikv', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_hel(_bob,_carol)/0->jhv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_david,_carol)/0->ikv', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_hel(_bob,_carol)/0->jhv']
# compare_form_pair_results [('2', ['A/p', 'u'], ['knl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['kng'], ['fft']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['frm'], ['qaq']), ('1', ['frm'], ['jhv']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['knl']), ('1', ['fft'], ['cbc']), ('1', ['zbhw'], ['agt']), ('1', ['ikv'], ['agt']), ('1', ['cbc'], ['agt'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_david,_carol)/0->ikv', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_hel(_bob,_carol)/0->jhv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_david,_carol)/0->ikv', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_hel(_bob,_carol)/0->jhv']
# compare_form_pair_results [('2', ['A/p', 'u'], ['knl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['kng'], ['fft']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['frm'], ['qaq']), ('1', ['frm'], ['jhv']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['knl']), ('1', ['fft'], ['cbc']), ('1', ['zbhw'], ['agt']), ('1', ['ikv'], ['agt']), ('1', ['cbc'], ['agt'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_david,_carol)/0->ikv', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_hel(_bob,_carol)/0->jhv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_david,_carol)/0->ikv', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_hel(_bob,_carol)/0->jhv']
# compare_form_pair_results [('2', ['A/p', 'u'], ['knl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['kng'], ['fft']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['frm'], ['qaq']), ('1', ['frm'], ['jhv']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['knl']), ('1', ['fft'], ['cbc']), ('1', ['zbhw'], ['agt']), ('1', ['ikv'], ['agt']), ('1', ['cbc'], ['agt'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_david,_carol)/0->ikv', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_hel(_bob,_carol)/0->jhv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_david,_carol)/0->ikv', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_hel(_bob,_carol)/0->jhv', 'S/_eat(_bob,_alice)/0->ozr', 'S/_get(_bob,_carol)/0->rsv', 'S/_eat(_alice,_carol)/0->tk', 'S/_hel(_carol,_alice)/0->eut', 'S/_eat(_alice,_bob)/0->trv']
# compare_form_pair_results [('2', ['A/p', 'u'], ['knl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['kng']), ('1', ['quw'], ['trv']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['lcm'], ['ozr']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['aha'], ['trv']), ('1', ['kng'], ['fft']), ('1', ['kng'], ['trv']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['nvdj'], ['ozr']), ('2', ['n', 'v', 'dj'], ['rs', 'v']), ('1', ['frm'], ['qaq']), ('1', ['frm'], ['jhv']), ('2', ['f', 'r', 'm'], ['oz', 'r']), ('2', ['f', 'r', 'm'], ['r', 'sv']), ('1', ['frm'], ['tk']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['knl']), ('1', ['fft'], ['cbc']), ('1', ['qaq'], ['ozr']), ('1', ['zbhw'], ['agt']), ('1', ['ikv'], ['agt']), ('10', ['ik', 'v'], ['rs', 'v']), ('1', ['cbc'], ['agt']), ('1', ['cbc'], ['eut']), ('10', ['jh', 'v'], ['rs', 'v']), ('01', ['t', 'k'], ['t', 'rv'])]
# filtered_indices_set [27, 30, 31]
# can_chunk_rule_set [['S/_get(_david,_carol)/0->ikv', 'S/_get(_bob,_carol)/0->rsv'], ['S/_hel(_bob,_carol)/0->jhv', 'S/_get(_bob,_carol)/0->rsv'], ['S/_eat(_alice,_carol)/0->tk', 'S/_eat(_alice,_bob)/0->trv']]
# split_sem_pairs [[['S', '_get', '_david', '_carol', '/0'], ['S', '_get', '_bob', '_carol', '/0']], [['S', '_hel', '_bob', '_carol', '/0'], ['S', '_get', '_bob', '_carol', '/0']], [['S', '_eat', '_alice', '_carol', '/0'], ['S', '_eat', '_alice', '_bob', '/0']]]
# index_sem_difference_sets [[2], [1], [3]]
# transform_only_form_chunk_pair_sets [['ikv', 'rsv'], ['jhv', 'rsv'], ['tk', 'trv']]
# split_form_pairs [(['ik', 'v'], ['rs', 'v']), (['jh', 'v'], ['rs', 'v']), (['t', 'k'], ['t', 'rv'])]
# index_form_difference_sets [[0], [0], [1]]
# used_labels {'A', 'Σ'}
# ===========-=========--
# チャンクしたペア [([['S', '_get', '_x', '_carol', '/0'], ['E/x', 'v']], [['E', '_david'], ['ik']], [['E', '_bob'], ['rs']]), ([['S', '_p', '_bob', '_carol', '/0'], ['Ω/p', 'v']], [['Ω', '_hel'], ['jh']], [['Ω', '_get'], ['rs']]), ([['S', '_eat', '_alice', '_y', '/0'], ['t', 'Ζ/y']], [['Ζ', '_carol'], ['k']], [['Ζ', '_bob'], ['rv']])]
# チャンク！ ['S/_get(_x,_carol)/0->E/xv', 'E/_david->ik', 'E/_bob->rs', 'S/_p(_bob,_carol)/0->Ω/pv', 'Ω/_hel->jh', 'Ω/_get->rs', 'S/_eat(_alice,_y)/0->tΖ/y', 'Ζ/_carol->k', 'Ζ/_bob->rv', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_eat(_carol,_bob)/0->kng', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_fuck(_carol,_david)/0->knl', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['Ζ/_carol->k', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut']
# compare_form_pair_results [('2', ['Ζ/x', 'ng'], ['quw']), ('2', ['Ζ/x', 'nl'], ['wff']), ('2', ['Ω/p', 'v'], ['frm']), ('1', ['quw'], ['lcm']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['lcm'], ['ozr']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['nvdj'], ['ozr']), ('1', ['frm'], ['qaq']), ('2', ['f', 'r', 'm'], ['oz', 'r']), ('1', ['wff'], ['qaq']), ('1', ['fft'], ['cbc']), ('1', ['qaq'], ['ozr']), ('1', ['zbhw'], ['agt']), ('1', ['cbc'], ['agt']), ('1', ['cbc'], ['eut'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'Ω', 'Σ', 'E', 'A', 'Ζ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'Ζ/_carol->k', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['Ζ/_carol->k', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut']
# compare_form_pair_results [('2', ['Ζ/x', 'ng'], ['quw']), ('2', ['Ζ/x', 'nl'], ['wff']), ('2', ['Ω/p', 'v'], ['frm']), ('1', ['quw'], ['lcm']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['lcm'], ['ozr']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['nvdj'], ['ozr']), ('1', ['frm'], ['qaq']), ('2', ['f', 'r', 'm'], ['oz', 'r']), ('1', ['wff'], ['qaq']), ('1', ['fft'], ['cbc']), ('1', ['qaq'], ['ozr']), ('1', ['zbhw'], ['agt']), ('1', ['cbc'], ['agt']), ('1', ['cbc'], ['eut'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'Ω', 'Σ', 'E', 'A', 'Ζ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'Ζ/_carol->k', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['Ζ/_carol->k', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut']
# compare_form_pair_results [('2', ['Ζ/x', 'ng'], ['quw']), ('2', ['Ζ/x', 'nl'], ['wff']), ('2', ['Ω/p', 'v'], ['frm']), ('1', ['quw'], ['lcm']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['lcm'], ['ozr']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['nvdj'], ['ozr']), ('1', ['frm'], ['qaq']), ('2', ['f', 'r', 'm'], ['oz', 'r']), ('1', ['wff'], ['qaq']), ('1', ['fft'], ['cbc']), ('1', ['qaq'], ['ozr']), ('1', ['zbhw'], ['agt']), ('1', ['cbc'], ['agt']), ('1', ['cbc'], ['eut'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'Ω', 'Σ', 'E', 'A', 'Ζ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'Ζ/_carol->k', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['Ζ/_carol->k', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'S/_fuck(_david,_bob)/0->lvzr', 'S/_hel(_alice,_carol)/0->lkk', 'S/_hel(_bob,_david)/0->zuk', 'S/_eat(_alice,_david)/0->tzl', 'S/_fuck(_alice,_david)/0->hfdt']
# compare_form_pair_results [('2', ['Ζ/x', 'ng'], ['quw']), ('2', ['Ζ/x', 'nl'], ['wff']), ('2', ['Ζ/x', 'nl'], ['hfdt']), ('2', ['Ω/p', 'v'], ['frm']), ('01', ['t', 'Ζ/y'], ['t', 'zl']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['lvzr']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['lcm'], ['ozr']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['nvdj'], ['ozr']), ('1', ['frm'], ['qaq']), ('2', ['f', 'r', 'm'], ['oz', 'r']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['zuk']), ('101', ['w', 'f', 'f'], ['h', 'f', 'dt']), ('1', ['fft'], ['cbc']), ('1', ['qaq'], ['ozr']), ('1', ['qaq'], ['zuk']), ('1', ['qaq'], ['tzl']), ('1', ['enf'], ['tzl']), ('2', ['en', 'f'], ['h', 'f', 'dt']), ('1', ['zbhw'], ['agt']), ('2', ['z', 'bhw'], ['lv', 'z', 'r']), ('1', ['cbc'], ['agt']), ('1', ['cbc'], ['eut']), ('11', ['t', 'zl'], ['hfd', 't'])]
# filtered_indices_set [4]
# can_chunk_rule_set [['S/_eat(_alice,_y)/0->tΖ/y', 'S/_eat(_alice,_david)/0->tzl']]
# split_sem_pairs [[['S', '_eat', '_alice', '_y', '/0'], ['S', '_eat', '_alice', '_david', '/0']]]
# index_sem_difference_sets [[3]]
# transform_only_form_chunk_pair_sets [['tΖ/y', 'tzl']]
# split_form_pairs [(['t', 'Ζ/y'], ['t', 'zl'])]
# index_form_difference_sets [[1]]
# used_labels {'Ω', 'Σ', 'E', 'A', 'Ζ'}
# ===========-=========--
# チャンクしたペア [([['S', '_eat', '_alice', '_y', '/0'], ['t', 'Ζ/y']], [['Ζ', '_david'], ['zl']])]
# チャンク！ ['S/_eat(_alice,_y)/0->tΖ/y', 'Ζ/_david->zl', 'S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'S/_fuck(_david,_bob)/0->lvzr', 'S/_hel(_alice,_carol)/0->lkk', 'S/_hel(_bob,_david)/0->zuk', 'S/_fuck(_alice,_david)/0->hfdt', 'Ζ/_carol->k', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['Ζ/_carol->k', 'Ζ/_david->zl', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_hel(_alice,_y)/0->lΖ/yk', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'S/_fuck(_david,_bob)/0->lvzr', 'S/_hel(_bob,_david)/0->zuk', 'S/_fuck(_alice,_david)/0->hfdt']
# compare_form_pair_results [('2', ['l', 'Ζ/y', 'k'], ['t', 'Ζ/y']), ('2', ['l', 'Ζ/y', 'k'], ['b', 'Σ/y']), ('2', ['Ζ/x', 'ng'], ['quw']), ('2', ['Ζ/x', 'nl'], ['wff']), ('2', ['Ζ/x', 'nl'], ['hfdt']), ('2', ['Ω/p', 'v'], ['frm']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['lvzr']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['lcm'], ['ozr']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['nvdj'], ['ozr']), ('1', ['frm'], ['qaq']), ('2', ['f', 'r', 'm'], ['oz', 'r']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['zuk']), ('101', ['w', 'f', 'f'], ['h', 'f', 'dt']), ('1', ['fft'], ['cbc']), ('1', ['qaq'], ['ozr']), ('1', ['qaq'], ['zuk']), ('2', ['en', 'f'], ['h', 'f', 'dt']), ('1', ['zbhw'], ['agt']), ('2', ['z', 'bhw'], ['lv', 'z', 'r']), ('1', ['cbc'], ['agt']), ('1', ['cbc'], ['eut'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'Ω', 'Σ', 'E', 'A', 'Ζ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_hel(_alice,_y)/0->lΖ/yk', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'S/_fuck(_david,_bob)/0->lvzr', 'S/_hel(_bob,_david)/0->zuk', 'S/_fuck(_alice,_david)/0->hfdt', 'Ζ/_carol->k', 'Ζ/_david->zl', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['Ζ/_carol->k', 'Ζ/_david->zl', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_hel(_alice,_y)/0->lΖ/yk', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'S/_fuck(_david,_bob)/0->lvzr', 'S/_hel(_bob,_david)/0->zuk', 'S/_fuck(_alice,_david)/0->hfdt']
# compare_form_pair_results [('2', ['l', 'Ζ/y', 'k'], ['t', 'Ζ/y']), ('2', ['l', 'Ζ/y', 'k'], ['b', 'Σ/y']), ('2', ['Ζ/x', 'ng'], ['quw']), ('2', ['Ζ/x', 'nl'], ['wff']), ('2', ['Ζ/x', 'nl'], ['hfdt']), ('2', ['Ω/p', 'v'], ['frm']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['lvzr']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['lcm'], ['ozr']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['nvdj'], ['ozr']), ('1', ['frm'], ['qaq']), ('2', ['f', 'r', 'm'], ['oz', 'r']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['zuk']), ('101', ['w', 'f', 'f'], ['h', 'f', 'dt']), ('1', ['fft'], ['cbc']), ('1', ['qaq'], ['ozr']), ('1', ['qaq'], ['zuk']), ('2', ['en', 'f'], ['h', 'f', 'dt']), ('1', ['zbhw'], ['agt']), ('2', ['z', 'bhw'], ['lv', 'z', 'r']), ('1', ['cbc'], ['agt']), ('1', ['cbc'], ['eut'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'Ω', 'Σ', 'E', 'A', 'Ζ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_hel(_alice,_y)/0->lΖ/yk', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'S/_fuck(_david,_bob)/0->lvzr', 'S/_hel(_bob,_david)/0->zuk', 'S/_fuck(_alice,_david)/0->hfdt', 'Ζ/_carol->k', 'Ζ/_david->zl', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['Ζ/_carol->k', 'Ζ/_david->zl', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_hel(_alice,_y)/0->lΖ/yk', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'S/_fuck(_david,_bob)/0->lvzr', 'S/_hel(_bob,_david)/0->zuk', 'S/_fuck(_alice,_david)/0->hfdt']
# compare_form_pair_results [('2', ['l', 'Ζ/y', 'k'], ['t', 'Ζ/y']), ('2', ['l', 'Ζ/y', 'k'], ['b', 'Σ/y']), ('2', ['Ζ/x', 'ng'], ['quw']), ('2', ['Ζ/x', 'nl'], ['wff']), ('2', ['Ζ/x', 'nl'], ['hfdt']), ('2', ['Ω/p', 'v'], ['frm']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['lvzr']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['lcm'], ['ozr']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['nvdj'], ['ozr']), ('1', ['frm'], ['qaq']), ('2', ['f', 'r', 'm'], ['oz', 'r']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['zuk']), ('101', ['w', 'f', 'f'], ['h', 'f', 'dt']), ('1', ['fft'], ['cbc']), ('1', ['qaq'], ['ozr']), ('1', ['qaq'], ['zuk']), ('2', ['en', 'f'], ['h', 'f', 'dt']), ('1', ['zbhw'], ['agt']), ('2', ['z', 'bhw'], ['lv', 'z', 'r']), ('1', ['cbc'], ['agt']), ('1', ['cbc'], ['eut'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'Ω', 'Σ', 'E', 'A', 'Ζ'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_hel(_alice,_y)/0->lΖ/yk', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'S/_fuck(_david,_bob)/0->lvzr', 'S/_hel(_bob,_david)/0->zuk', 'S/_fuck(_alice,_david)/0->hfdt', 'Ζ/_carol->k', 'Ζ/_david->zl', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# word_rule_set ['Ζ/_carol->k', 'Ζ/_david->zl', 'E/_david->ik', 'E/_bob->rs', 'Ω/_hel->jh', 'Ω/_get->rs', 'Ζ/_bob->rv', 'A/_eat->jv', 'A/_hel->zn', 'Σ/_bob->nfr', 'Σ/_alice->je']
# rule_set ['S/_hel(_alice,_y)/0->lΖ/yk', 'S/_eat(_alice,_y)/0->tΖ/y', 'S/_eat(_x,_bob)/0->Ζ/xng', 'S/_fuck(_x,_david)/0->Ζ/xnl', 'S/_get(_x,_carol)/0->E/xv', 'S/_p(_bob,_carol)/0->Ω/pv', 'S/_p(_carol,_david)/0->A/pu', 'S/_hel(_david,_y)/0->bΣ/y', 'S/_eat(_david,_bob)/0->quw', 'S/_eat(_david,_alice)/0->lcm', 'S/_get(_alice,_bob)/0->aha', 'S/_get(_bob,_alice)/0->nvdj', 'S/_eat(_bob,_carol)/0->frm', 'S/_fuck(_bob,_david)/0->wff', 'S/_get(_carol,_bob)/0->fft', 'S/_eat(_bob,_david)/0->qaq', 'S/_get(_alice,_david)/0->enf', 'S/_fuck(_david,_alice)/0->zbhw', 'S/_get(_carol,_alice)/0->cbc', 'S/_get(_david,_alice)/0->agt', 'S/_eat(_bob,_alice)/0->ozr', 'S/_hel(_carol,_alice)/0->eut', 'S/_fuck(_david,_bob)/0->lvzr', 'S/_hel(_bob,_david)/0->zuk', 'S/_fuck(_alice,_david)/0->hfdt', 'S/_get(_carol,_david)/0->mu', 'S/_get(_bob,_david)/0->wro', 'S/_eat(_carol,_alice)/0->ubg', 'S/_hel(_carol,_bob)/0->wdz', 'S/_fuck(_alice,_carol)/0->bcjr']
# compare_form_pair_results [('2', ['l', 'Ζ/y', 'k'], ['t', 'Ζ/y']), ('2', ['l', 'Ζ/y', 'k'], ['b', 'Σ/y']), ('2', ['Ζ/x', 'ng'], ['quw']), ('2', ['Ζ/x', 'nl'], ['wff']), ('2', ['Ζ/x', 'nl'], ['hfdt']), ('2', ['Ω/p', 'v'], ['frm']), ('10', ['A/p', 'u'], ['m', 'u']), ('1', ['quw'], ['lcm']), ('1', ['quw'], ['lvzr']), ('1', ['lcm'], ['zbhw']), ('1', ['lcm'], ['agt']), ('1', ['lcm'], ['ozr']), ('1', ['lcm'], ['ubg']), ('1', ['aha'], ['fft']), ('1', ['aha'], ['enf']), ('1', ['nvdj'], ['cbc']), ('1', ['nvdj'], ['agt']), ('1', ['nvdj'], ['ozr']), ('1', ['nvdj'], ['wro']), ('1', ['frm'], ['qaq']), ('2', ['f', 'r', 'm'], ['oz', 'r']), ('1', ['wff'], ['qaq']), ('1', ['wff'], ['zuk']), ('101', ['w', 'f', 'f'], ['h', 'f', 'dt']), ('01', ['w', 'ff'], ['w', 'ro']), ('1', ['fft'], ['cbc']), ('1', ['fft'], ['mu']), ('1', ['fft'], ['wdz']), ('1', ['qaq'], ['ozr']), ('1', ['qaq'], ['zuk']), ('1', ['qaq'], ['wro']), ('2', ['en', 'f'], ['h', 'f', 'dt']), ('1', ['enf'], ['mu']), ('1', ['enf'], ['wro']), ('1', ['zbhw'], ['agt']), ('2', ['z', 'bhw'], ['lv', 'z', 'r']), ('1', ['cbc'], ['agt']), ('1', ['cbc'], ['eut']), ('1', ['cbc'], ['mu']), ('101', ['c', 'b', 'c'], ['u', 'b', 'g']), ('1', ['ozr'], ['ubg']), ('2', ['e', 'u', 't'], ['u', 'bg']), ('1', ['eut'], ['wdz']), ('1', ['zuk'], ['wro']), ('1', ['hfdt'], ['bcjr']), ('1', ['mu'], ['wro'])]
# filtered_indices_set [6, 24]
# can_chunk_rule_set [['S/_p(_carol,_david)/0->A/pu', 'S/_get(_carol,_david)/0->mu'], ['S/_fuck(_bob,_david)/0->wff', 'S/_get(_bob,_david)/0->wro']]
# split_sem_pairs [[['S', '_p', '_carol', '_david', '/0'], ['S', '_get', '_carol', '_david', '/0']], [['S', '_fuck', '_bob', '_david', '/0'], ['S', '_get', '_bob', '_david', '/0']]]
# index_sem_difference_sets [[1], [1]]
# transform_only_form_chunk_pair_sets [['A/pu', 'mu'], ['wff', 'wro']]
# split_form_pairs [(['A/p', 'u'], ['m', 'u']), (['w', 'ff'], ['w', 'ro'])]
# index_form_difference_sets [[0], [1]]
# used_labels {'Ω', 'Σ', 'E', 'A', 'Ζ'}
# ===========-=========--
# チャンクしたペア [([['S', '_p', '_carol', '_david', '/0'], ['A/p', 'u']], [['A', '_get'], ['m']]), ([['S', '_p', '_bob', '_david', '/0'], ['w', 'K/p']], [['K', '_fuck'], ['ff']], [['K', '_get'], ['ro']])]
# ...
# word_rule_set ['Q/_alice->v', 'Q/_fuck->t', 'Q/_david->m', 'Q/_eat->m', 'M/_carol->rzm', 'M/_david->o']
# rule_set ['S/_eat(_carol,_y)/0->Q/yjc', 'S/_p(_david,_alice)/0->bQ/p', 'S/_hel(_bob,_y)/0->mcQ/yn', 'S/_get(_bob,_y)/0->cjiqQ/y', 'S/_eat(_bob,_y)/0->gnfdwzQ/yratcaglfc', 'S/_p(_alice,_david)/0->tQ/p', 'S/_get(_x,_alice)/0->bM/x', 'S/_hel(_david,_bob)/0->tfh', 'S/_fuck(_carol,_bob)/0->onfdwzra', 'S/_get(_david,_carol)/0->jdjckr', 'S/_get(_bob,_carol)/0->heia', 'S/_hel(_carol,_bob)/0->djekl', 'S/_get(_bob,_david)/0->bggcij', 'S/_hel(_david,_carol)/0->kjibiu', 'S/_hel(_bob,_carol)/0->uzjbch', 'S/_get(_carol,_bob)/0->gtragcij', 'S/_help(_alice,_bob)/0->to', 'S/_eat(_david,_bob)/0->mzfc', 'S/_hel(_david,_alice)/0->bc', 'S/_fuck(_bob,_carol)/0->awnfdwzwgccjcgi', 'S/_fuck(_alice,_bob)/0->tj']
# compare_form_pair_results [('2', ['Q/y', 'j', 'c'], ['gnfdwz', 'Q/y', 'rat', 'c', 'aglfc']), ('01', ['b', 'Q/p'], ['b', 'c']), ('2', ['m', 'c', 'Q/y', 'n'], ['c', 'jiq', 'Q/y']), ('101', ['mc', 'Q/y', 'n'], ['gnfdwz', 'Q/y', 'ratcaglfc']), ('2', ['m', 'c', 'Q/y', 'n'], ['uzjb', 'c', 'h']), ('2', ['cjiq', 'Q/y'], ['gnfdwz', 'Q/y', 'ratcaglfc']), ('2', ['cj', 'i', 'q', 'Q/y'], ['he', 'i', 'a']), ('1111', ['c', 'j', 'iq', 'Q/y'], ['bgg', 'c', 'i', 'j']), ('1', ['tfh'], ['djekl']), ('1', ['tfh'], ['kjibiu']), ('101', ['t', 'f', 'h'], ['mz', 'f', 'c']), ('1', ['tfh'], ['bc']), ('2', ['onf', 'd', 'wzra'], ['d', 'jekl']), ('2', ['onfdwz', 'ra'], ['gt', 'ra', 'gcij']), ('1', ['onfdwzra'], ['tj']), ('1', ['jdjckr'], ['heia']), ('2', ['j', 'djckr'], ['k', 'j', 'ibiu']), ('101', ['he', 'i', 'a'], ['bggc', 'i', 'j']), ('11', ['h', 'eia'], ['uzjbc', 'h']), ('2', ['he', 'i', 'a'], ['awnfdwzwgccjcg', 'i']), ('2', ['d', 'j', 'ekl'], ['gtragci', 'j']), ('2', ['k', 'j', 'i', 'b', 'iu'], ['uz', 'j', 'b', 'ch']), ('2', ['kji', 'b', 'iu'], ['b', 'c']), ('101101', ['u', 'z', 'j', 'b', 'c', 'h'], ['awnfdw', 'z', 'wgcc', 'j', 'c', 'gi']), ('01', ['t', 'o'], ['t', 'j'])]
# filtered_indices_set [1, 24]
# can_chunk_rule_set [['S/_p(_david,_alice)/0->bQ/p', 'S/_hel(_david,_alice)/0->bc'], ['S/_help(_alice,_bob)/0->to', 'S/_fuck(_alice,_bob)/0->tj']]
# split_sem_pairs [[['S', '_p', '_david', '_alice', '/0'], ['S', '_hel', '_david', '_alice', '/0']], [['S', '_help', '_alice', '_bob', '/0'], ['S', '_fuck', '_alice', '_bob', '/0']]]
# index_sem_difference_sets [[1], [1]]
# transform_only_form_chunk_pair_sets [['bQ/p', 'bc'], ['to', 'tj']]
# split_form_pairs [(['b', 'Q/p'], ['b', 'c']), (['t', 'o'], ['t', 'j'])]
# index_form_difference_sets [[1], [1]]
# used_labels {'M', 'Q'}
# ===========-=========--
# チャンクしたペア [([['S', '_p', '_david', '_alice', '/0'], ['b', 'Q/p']], [['Q', '_hel'], ['c']]), ([['S', '_p', '_alice', '_bob', '/0'], ['t', 'Τ/p']], [['Τ', '_help'], ['o']], [['Τ', '_fuck'], ['j']])]
# チャンク！ ['S/_p(_david,_alice)/0->bQ/p', 'Q/_hel->c', 'S/_p(_alice,_bob)/0->tΤ/p', 'Τ/_help->o', 'Τ/_fuck->j', 'S/_eat(_carol,_y)/0->Q/yjc', 'S/_hel(_bob,_y)/0->mcQ/yn', 'S/_get(_bob,_y)/0->cjiqQ/y', 'S/_eat(_bob,_y)/0->gnfdwzQ/yratcaglfc', 'S/_p(_alice,_david)/0->tQ/p', 'S/_get(_x,_alice)/0->bM/x', 'S/_hel(_david,_bob)/0->tfh', 'S/_fuck(_carol,_bob)/0->onfdwzra', 'S/_get(_david,_carol)/0->jdjckr', 'S/_get(_bob,_carol)/0->heia', 'S/_hel(_carol,_bob)/0->djekl', 'S/_get(_bob,_david)/0->bggcij', 'S/_hel(_david,_carol)/0->kjibiu', 'S/_hel(_bob,_carol)/0->uzjbch', 'S/_get(_carol,_bob)/0->gtragcij', 'S/_eat(_david,_bob)/0->mzfc', 'S/_fuck(_bob,_carol)/0->awnfdwzwgccjcgi', 'Q/_alice->v', 'Q/_fuck->t', 'Q/_david->m', 'Q/_eat->m', 'M/_carol->rzm', 'M/_david->o']
# word_rule_set ['Q/_hel->c', 'Ν/_fuck->j', 'Q/_david->m', 'Q/_eat->m', 'Ν/_help->o', 'Q/_alice->v', 'Q/_fuck->t', 'M/_carol->rzm', 'M/_david->o']
# rule_set ['S/_p(_bob,_y)/0->mQ/pQ/yn', 'S/_p(_bob,_carol)/0->uzjbQ/ph', 'S/_p(_bob,_carol)/0->awnfdwzwgccΝ/pcgi', 'S/_eat(_x,_bob)/0->Q/xzfc', 'S/_p(_david,_bob)/0->Q/pzfc', 'S/_p(_david,_alice)/0->bQ/p', 'S/_p(_alice,_bob)/0->tΝ/p', 'S/_eat(_carol,_y)/0->Q/yjc', 'S/_get(_bob,_y)/0->cjiqQ/y', 'S/_eat(_bob,_y)/0->gnfdwzQ/yratcaglfc', 'S/_p(_alice,_david)/0->tQ/p', 'S/_get(_x,_alice)/0->bM/x', 'S/_hel(_david,_bob)/0->tfh', 'S/_fuck(_carol,_bob)/0->onfdwzra', 'S/_get(_david,_carol)/0->jdjckr', 'S/_get(_bob,_carol)/0->heia', 'S/_hel(_carol,_bob)/0->djekl', 'S/_get(_bob,_david)/0->bggcij', 'S/_hel(_david,_carol)/0->kjibiu', 'S/_get(_carol,_bob)/0->gtragcij']
# compare_form_pair_results [('2', ['m', 'Q/p', 'Q/y', 'n'], ['awnfdwzwgcc', 'Ν/p', 'cgi']), ('2', ['m', 'Q/p', 'Q/y', 'n'], ['awnfdwzwgcc', 'Ν/p', 'cgi']), ('2', ['m', 'Q/p', 'Q/y', 'n'], ['cjiq', 'Q/y']), ('2', ['m', 'Q/p', 'Q/y', 'n'], ['gnfdwz', 'Q/y', 'ratcaglfc']), ('2', ['a', 'wnfdwzwgcc', 'Ν/p', 'cgi'], ['hei', 'a']), ('2', ['a', 'wnfdwzwgcc', 'Ν/p', 'cgi'], ['hei', 'a']), ('11', ['Q/p', 'zfc'], ['b', 'Q/p']), ('11', ['Q/p', 'zfc'], ['t', 'Ν/p']), ('2', ['Q/p', 'z', 'f', 'c'], ['t', 'f', 'h']), ('01', ['t', 'Ν/p'], ['t', 'Q/p']), ('2', ['Q/y', 'j', 'c'], ['gnfdwz', 'Q/y', 'rat', 'c', 'aglfc']), ('2', ['cjiq', 'Q/y'], ['gnfdwz', 'Q/y', 'ratcaglfc']), ('2', ['cj', 'i', 'q', 'Q/y'], ['he', 'i', 'a']), ('1111', ['c', 'j', 'iq', 'Q/y'], ['bgg', 'c', 'i', 'j']), ('1', ['tfh'], ['djekl']), ('1', ['tfh'], ['kjibiu']), ('2', ['onf', 'd', 'wzra'], ['d', 'jekl']), ('2', ['onfdwz', 'ra'], ['gt', 'ra', 'gcij']), ('1', ['jdjckr'], ['heia']), ('2', ['j', 'djckr'], ['k', 'j', 'ibiu']), ('101', ['he', 'i', 'a'], ['bggc', 'i', 'j']), ('2', ['d', 'j', 'ekl'], ['gtragci', 'j'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'M', 'Q', 'Ν'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_bob,_y)/0->mQ/pQ/yn', 'S/_p(_bob,_carol)/0->uzjbQ/ph', 'S/_p(_bob,_carol)/0->awnfdwzwgccΝ/pcgi', 'S/_eat(_x,_bob)/0->Q/xzfc', 'S/_p(_david,_bob)/0->Q/pzfc', 'S/_p(_david,_alice)/0->bQ/p', 'S/_p(_alice,_bob)/0->tΝ/p', 'S/_eat(_carol,_y)/0->Q/yjc', 'S/_get(_bob,_y)/0->cjiqQ/y', 'S/_eat(_bob,_y)/0->gnfdwzQ/yratcaglfc', 'S/_p(_alice,_david)/0->tQ/p', 'S/_get(_x,_alice)/0->bM/x', 'S/_hel(_david,_bob)/0->tfh', 'S/_fuck(_carol,_bob)/0->onfdwzra', 'S/_get(_david,_carol)/0->jdjckr', 'S/_get(_bob,_carol)/0->heia', 'S/_hel(_carol,_bob)/0->djekl', 'S/_get(_bob,_david)/0->bggcij', 'S/_hel(_david,_carol)/0->kjibiu', 'S/_get(_carol,_bob)/0->gtragcij', 'Q/_hel->c', 'Ν/_fuck->j', 'Q/_david->m', 'Q/_eat->m', 'Ν/_help->o', 'Q/_alice->v', 'Q/_fuck->t', 'M/_carol->rzm', 'M/_david->o']
# word_rule_set ['Q/_hel->c', 'I/_fuck->j', 'Q/_david->m', 'Q/_eat->m', 'I/_help->o', 'Q/_alice->v', 'Q/_fuck->t', 'M/_carol->rzm', 'M/_david->o']
# rule_set ['S/_p(_bob,_y)/0->mQ/pQ/yn', 'S/_p(_bob,_carol)/0->uzjbQ/ph', 'S/_p(_bob,_carol)/0->awnfdwzwgccI/pcgi', 'S/_eat(_x,_bob)/0->Q/xzfc', 'S/_p(_david,_bob)/0->Q/pzfc', 'S/_p(_david,_alice)/0->bQ/p', 'S/_p(_alice,_bob)/0->tI/p', 'S/_eat(_carol,_y)/0->Q/yjc', 'S/_get(_bob,_y)/0->cjiqQ/y', 'S/_eat(_bob,_y)/0->gnfdwzQ/yratcaglfc', 'S/_p(_alice,_david)/0->tQ/p', 'S/_get(_x,_alice)/0->bM/x', 'S/_hel(_david,_bob)/0->tfh', 'S/_fuck(_carol,_bob)/0->onfdwzra', 'S/_get(_david,_carol)/0->jdjckr', 'S/_get(_bob,_carol)/0->heia', 'S/_hel(_carol,_bob)/0->djekl', 'S/_get(_bob,_david)/0->bggcij', 'S/_hel(_david,_carol)/0->kjibiu', 'S/_get(_carol,_bob)/0->gtragcij']
# compare_form_pair_results [('2', ['m', 'Q/p', 'Q/y', 'n'], ['awnfdwzwgcc', 'I/p', 'cgi']), ('2', ['m', 'Q/p', 'Q/y', 'n'], ['awnfdwzwgcc', 'I/p', 'cgi']), ('2', ['m', 'Q/p', 'Q/y', 'n'], ['cjiq', 'Q/y']), ('2', ['m', 'Q/p', 'Q/y', 'n'], ['gnfdwz', 'Q/y', 'ratcaglfc']), ('2', ['a', 'wnfdwzwgcc', 'I/p', 'cgi'], ['hei', 'a']), ('2', ['a', 'wnfdwzwgcc', 'I/p', 'cgi'], ['hei', 'a']), ('11', ['Q/p', 'zfc'], ['b', 'Q/p']), ('11', ['Q/p', 'zfc'], ['t', 'I/p']), ('2', ['Q/p', 'z', 'f', 'c'], ['t', 'f', 'h']), ('01', ['t', 'I/p'], ['t', 'Q/p']), ('2', ['Q/y', 'j', 'c'], ['gnfdwz', 'Q/y', 'rat', 'c', 'aglfc']), ('2', ['cjiq', 'Q/y'], ['gnfdwz', 'Q/y', 'ratcaglfc']), ('2', ['cj', 'i', 'q', 'Q/y'], ['he', 'i', 'a']), ('1111', ['c', 'j', 'iq', 'Q/y'], ['bgg', 'c', 'i', 'j']), ('1', ['tfh'], ['djekl']), ('1', ['tfh'], ['kjibiu']), ('2', ['onf', 'd', 'wzra'], ['d', 'jekl']), ('2', ['onfdwz', 'ra'], ['gt', 'ra', 'gcij']), ('1', ['jdjckr'], ['heia']), ('2', ['j', 'djckr'], ['k', 'j', 'ibiu']), ('101', ['he', 'i', 'a'], ['bggc', 'i', 'j']), ('2', ['d', 'j', 'ekl'], ['gtragci', 'j'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'M', 'Q', 'I'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_bob,_y)/0->mQ/pQ/yn', 'S/_p(_bob,_carol)/0->uzjbQ/ph', 'S/_p(_bob,_carol)/0->awnfdwzwgccI/pcgi', 'S/_eat(_x,_bob)/0->Q/xzfc', 'S/_p(_david,_bob)/0->Q/pzfc', 'S/_p(_david,_alice)/0->bQ/p', 'S/_p(_alice,_bob)/0->tI/p', 'S/_eat(_carol,_y)/0->Q/yjc', 'S/_get(_bob,_y)/0->cjiqQ/y', 'S/_eat(_bob,_y)/0->gnfdwzQ/yratcaglfc', 'S/_p(_alice,_david)/0->tQ/p', 'S/_get(_x,_alice)/0->bM/x', 'S/_hel(_david,_bob)/0->tfh', 'S/_fuck(_carol,_bob)/0->onfdwzra', 'S/_get(_david,_carol)/0->jdjckr', 'S/_get(_bob,_carol)/0->heia', 'S/_hel(_carol,_bob)/0->djekl', 'S/_get(_bob,_david)/0->bggcij', 'S/_hel(_david,_carol)/0->kjibiu', 'S/_get(_carol,_bob)/0->gtragcij', 'Q/_hel->c', 'I/_fuck->j', 'Q/_david->m', 'Q/_eat->m', 'I/_help->o', 'Q/_alice->v', 'Q/_fuck->t', 'M/_carol->rzm', 'M/_david->o']
# word_rule_set ['Q/_hel->c', 'Q/_fuck->j', 'Q/_david->m', 'Q/_eat->m', 'Q/_help->o', 'Q/_alice->v', 'Q/_fuck->t', 'M/_carol->rzm', 'M/_david->o']
# rule_set ['S/_p(_bob,_y)/0->mQ/pQ/yn', 'S/_p(_bob,_carol)/0->uzjbQ/ph', 'S/_p(_bob,_carol)/0->awnfdwzwgccQ/pcgi', 'S/_eat(_x,_bob)/0->Q/xzfc', 'S/_p(_david,_bob)/0->Q/pzfc', 'S/_p(_david,_alice)/0->bQ/p', 'S/_p(_alice,_bob)/0->tQ/p', 'S/_eat(_carol,_y)/0->Q/yjc', 'S/_get(_bob,_y)/0->cjiqQ/y', 'S/_eat(_bob,_y)/0->gnfdwzQ/yratcaglfc', 'S/_p(_alice,_david)/0->tQ/p', 'S/_get(_x,_alice)/0->bM/x', 'S/_hel(_david,_bob)/0->tfh', 'S/_fuck(_carol,_bob)/0->onfdwzra', 'S/_get(_david,_carol)/0->jdjckr', 'S/_get(_bob,_carol)/0->heia', 'S/_hel(_carol,_bob)/0->djekl', 'S/_get(_bob,_david)/0->bggcij', 'S/_hel(_david,_carol)/0->kjibiu', 'S/_get(_carol,_bob)/0->gtragcij']
# compare_form_pair_results [('2', ['m', 'Q/p', 'Q/y', 'n'], ['awnfdwzwgcc', 'Q/p', 'cgi']), ('2', ['m', 'Q/p', 'Q/y', 'n'], ['awnfdwzwgcc', 'Q/p', 'cgi']), ('2', ['m', 'Q/p', 'Q/y', 'n'], ['cjiq', 'Q/y']), ('2', ['m', 'Q/p', 'Q/y', 'n'], ['gnfdwz', 'Q/y', 'ratcaglfc']), ('2', ['a', 'wnfdwzwgcc', 'Q/p', 'cgi'], ['hei', 'a']), ('2', ['a', 'wnfdwzwgcc', 'Q/p', 'cgi'], ['hei', 'a']), ('11', ['Q/p', 'zfc'], ['b', 'Q/p']), ('11', ['Q/p', 'zfc'], ['t', 'Q/p']), ('2', ['Q/p', 'z', 'f', 'c'], ['t', 'f', 'h']), ('00', ['t', 'Q/p'], ['t', 'Q/p']), ('2', ['Q/y', 'j', 'c'], ['gnfdwz', 'Q/y', 'rat', 'c', 'aglfc']), ('2', ['cjiq', 'Q/y'], ['gnfdwz', 'Q/y', 'ratcaglfc']), ('2', ['cj', 'i', 'q', 'Q/y'], ['he', 'i', 'a']), ('1111', ['c', 'j', 'iq', 'Q/y'], ['bgg', 'c', 'i', 'j']), ('1', ['tfh'], ['djekl']), ('1', ['tfh'], ['kjibiu']), ('2', ['onf', 'd', 'wzra'], ['d', 'jekl']), ('2', ['onfdwz', 'ra'], ['gt', 'ra', 'gcij']), ('1', ['jdjckr'], ['heia']), ('2', ['j', 'djckr'], ['k', 'j', 'ibiu']), ('101', ['he', 'i', 'a'], ['bggc', 'i', 'j']), ('2', ['d', 'j', 'ekl'], ['gtragci', 'j'])]
# filtered_indices_set []
# can_chunk_rule_set []
# split_sem_pairs []
# index_sem_difference_sets []
# transform_only_form_chunk_pair_sets []
# split_form_pairs []
# index_form_difference_sets []
# used_labels {'M', 'Q'}
# ===========-=========--
# チャンクしたペア []
# チャンク！ ['S/_p(_bob,_y)/0->mQ/pQ/yn', 'S/_p(_bob,_carol)/0->uzjbQ/ph', 'S/_p(_bob,_carol)/0->awnfdwzwgccQ/pcgi', 'S/_eat(_x,_bob)/0->Q/xzfc', 'S/_p(_david,_bob)/0->Q/pzfc', 'S/_p(_david,_alice)/0->bQ/p', 'S/_p(_alice,_bob)/0->tQ/p', 'S/_eat(_carol,_y)/0->Q/yjc', 'S/_get(_bob,_y)/0->cjiqQ/y', 'S/_eat(_bob,_y)/0->gnfdwzQ/yratcaglfc', 'S/_p(_alice,_david)/0->tQ/p', 'S/_get(_x,_alice)/0->bM/x', 'S/_hel(_david,_bob)/0->tfh', 'S/_fuck(_carol,_bob)/0->onfdwzra', 'S/_get(_david,_carol)/0->jdjckr', 'S/_get(_bob,_carol)/0->heia', 'S/_hel(_carol,_bob)/0->djekl', 'S/_get(_bob,_david)/0->bggcij', 'S/_hel(_david,_carol)/0->kjibiu', 'S/_get(_carol,_bob)/0->gtragcij', 'Q/_hel->c', 'Q/_fuck->j', 'Q/_david->m', 'Q/_eat->m', 'Q/_help->o', 'Q/_alice->v', 'Q/_fuck->t', 'M/_carol->rzm', 'M/_david->o']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 230
#     227 print(f"Experiment with seed: {seed}")  # シードの表示
#     229 # シミュレーションの実行
# --> 230 parent_production, child_samples, child_memory, topsim_values, normalized_topsim_values, ibuki_1_topsim_values, expressivity_values, chunk_application_counts, category_integration_counts, replace_application_counts = simulate_language_evolution(
#     231     n_gens=N_GENS,
#     232     n_samples=N_SAMPLES,
#     233     initial_language_file=INITIAL_LANGUAGE_FILE,
#     234     semantic_space_file=SEMANTIC_SPACE_FILE,
#     235     holistic_rule_invention_length=HOLISTIC_RULE_INVENTION_LENGTH,
#     236     word_rule_invention_length=WORD_RULE_INVENTION_LENGTH,
#     237     random_seed=seed,  # 各シードで実行
#     238     iterations=ITERATIONS,
#     239     batch_size=BATCH_SIZE,
#     240     max_form_length=MAX_FORM_LENGTH,  # 形式の最大長さ
#     241     front_keep_length=FRONT_KEEP_LENGTH,  # 前半に残す長さ
#     242     shortening_interval=SHORTENING_INTERVAL
#     243 )
#     245 # 結果の表示
#     246 print(f"最終世代の発話seed{seed}:", parent_production)
#
# Cell In[1], line 186, in simulate_language_evolution(n_gens, n_samples, initial_language_file, semantic_space_file, holistic_rule_invention_length, word_rule_invention_length, random_seed, iterations, batch_size, max_form_length, front_keep_length, shortening_interval)
#     184 topsim_values.append(TopSim.TopSim(parent.production))
#     185 normalized_topsim_values.append(Normalized_TopSim(parent.production))
# --> 186 ibuki_1_topsim_values.append(Ibuki_1_TopSim(parent.production))  # Ibuki_1_TopSim値の追加
#     189 # 各世代のExpressivity値を計算
#     190 all_meanings = sample_meaning_space(semantic_space_file)
#
# File ~/master_ILM/topsim/Ibuki_1_TopSim.py:264, in Ibuki_1_TopSim(rule_set)
#     262 standard_deviation_of_hamming_distance = standard_deviation_of_hamming_distance_process(variance_of_hamming_distance)
#     263 form_set = set_form(rule_set)
# --> 264 total_distance, average_levenshtein_distance, pair_count = ibuki_form_distance_process(form_set)
#     265 variance_of_levenshtein_distance, average_distance, pair_count = variance_of_levenshtein_distance_process(form_set)
#     266 standard_deviation_of_levenshtein_distance = standard_deviation_of_levenshtein_distance_process(variance_of_levenshtein_distance)
#
# File ~/master_ILM/topsim/Ibuki_1_TopSim.py:194, in ibuki_form_distance_process(form_set)
#     191 pairs = combinations(form_set, 2)
#     193 for form1, form2 in pairs:
# --> 194     distance = ibuki_form_distance_ability(form1, form2)
#     195     # print(f"'{form1}' と '{form2}' の Levenshtein distance は {distance}")
#     196     total_distance += distance
#
# File ~/master_ILM/topsim/Ibuki_1_TopSim.py:175, in ibuki_form_distance_ability(form1, form2)
#     173 def ibuki_form_distance_ability(form1, form2):
# --> 175     levenshtein_distance = levenshtein_distance_ability(form1, form2)
#     176     split_form1, split_form2 = split_form_ability(form1, form2)
#     177     replaced_form1, replaced_form2 = replace_and_return_lists_ability(split_form1, split_form2)
#
# File ~/master_ILM/topsim/Ibuki_1_TopSim.py:121, in levenshtein_distance_ability(form1, form2)
#     118         else:
#     119             left_upp = dp[i - 1][j - 1] + 1
# --> 121         dp[i][j] = min(left, upp, left_upp)
#     123 # 編集距離を返す
#     124 levenshtein_distance =  dp[t_l - 1][s_l - 1]
#
# KeyboardInterrupt:
